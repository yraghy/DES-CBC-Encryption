# %% [markdown]
# # Starter Notebook: DES Encryption with CBC Mode

# %%
# DES Encryption with CBC Mode
# Group Members: Youssef Ahmed Elraghy / 13001467 / P02
#                Abdelrahman Mostafa   / 13002064 / P02

# DES Tables
IP = [58, 50, 42, 34, 26, 18, 10, 2, 60, 52, 44, 36, 28, 20, 12, 4,
      62, 54, 46, 38, 30, 22, 14, 6, 64, 56, 48, 40, 32, 24, 16, 8,
      57, 49, 41, 33, 25, 17, 9, 1, 59, 51, 43, 35, 27, 19, 11, 3,
      61, 53, 45, 37, 29, 21, 13, 5, 63, 55, 47, 39, 31, 23, 15, 7]

FP = [40, 8, 48, 16, 56, 24, 64, 32, 39, 7, 47, 15, 55, 23, 63, 31,
      38, 6, 46, 14, 54, 22, 62, 30, 37, 5, 45, 13, 53, 21, 61, 29,
      36, 4, 44, 12, 52, 20, 60, 28, 35, 3, 43, 11, 51, 19, 59, 27,
      34, 2, 42, 10, 50, 18, 58, 26, 33, 1, 41, 9, 49, 17, 57, 25]

E = [32, 1, 2, 3, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 10, 11, 12, 13, 12, 13, 14, 15, 16, 17,
     16, 17, 18, 19, 20, 21, 20, 21, 22, 23, 24, 25, 24, 25, 26, 27, 28, 29, 28, 29, 30, 31, 32, 1]

P = [16, 7, 20, 21, 29, 12, 28, 17, 1, 15, 23, 26, 5, 18, 31, 10,
     2, 8, 24, 14, 32, 27, 3, 9, 19, 13, 30, 6, 22, 11, 4, 25]

S_BOXES = [
    [[14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7],
     [0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8],
     [4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0],
     [15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13]],

    [[15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10],
     [3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5],
     [0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15],
     [13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9]],

    [[10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8],
     [13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1],
     [13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7],
     [1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12]],

    [[7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15],
     [13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9],
     [10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4],
     [3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14]],

    [[2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9],
     [14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6],
     [4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14],
     [11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3]],

    [[12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11],
     [10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8],
     [9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6],
     [4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13]],

    [[4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1],
     [13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6],
     [1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2],
     [6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12]],

    [[13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7],
     [1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2],
     [7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8],
     [2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11]]
]

# 16 round keys (48 bits each)
round_keys = ["010101010101010101010101010101010101010101010101" for _ in range(16)]

# %%
from bitarray import bitarray

# permutation method -> swaps bits according to ptable
def permute(block, Ptable):
    return bitarray([block[i-1] for i in Ptable])

# xor method for xoring step of DES
def xor(b1, b2):
    return bitarray([b1[i] != b2[i] for i in range(len(b1))])

# text to bits conversion method (includes padding)
def t2b(text, size=64):
    bits = bitarray()
    bits.frombytes(text.encode('utf-8'))
    while len(bits) < size:
        bits.extend('0')
    return bits[:size]

# bits to text conversion method
def b2t(bits):
    return bits.tobytes().decode('utf-8', 'ignore')

# s-box substitutions
def s_box(bits):
    output = bitarray()
    for i in range(8):
        chunk = bits[i*6:(i+1)*6]
        row = int(str(chunk[0]) + str(chunk[5]), 2)
        col = int(chunk[1:5].to01(), 2)
        output.extend(f"{S_BOXES[i][row][col]:04b}")
    return output

# feistel function method
def feistel(right, key):
    expand = permute(right, E)
    xord = xor(expand, key)
    sub = s_box(xord)
    return permute(sub, P)

def encrypt(pt, keys):
    bin_text = t2b(pt)
    permuted = permute(bin_text, IP)
    left, right = permuted[:32], permuted[32:]
    j = 0
    for key in keys:
        new_r = xor(left, feistel(right, key))
        left, right = right, new_r
        print(f"This is round {j}, right: {right}, left: {left}")
        j += 1

    combined = left + right
    ct = permute(combined, FP)

    return hex(int(ct.to01(), 2))[2:].upper()

def decrypt(ct, keys):
    bin_text = bitarray(bin(int(ct, 16))[2:].zfill(64))
    permuted = permute(bin_text, IP)
    left, right = permuted[:32], permuted[32:]
    j = 0
    for key in reversed(keys):
        new_r = xor(left, feistel(right, key))
        left, right = right, new_r
        print(f"This is round {j}, right: {right}, left: {left}")
        j += 1

    combined = left + right
    pt_bits = permute(combined, FP)

    return b2t(pt_bits)

# %%
pt = "HELLO123"
ct = encrypt(pt, round_keys)
print('\nCiphertext after DES encryption:', ct)
print('Now decrypting ciphertext')
pt2 = decrypt(ct, round_keys)
print('\nPlaintext after DES decryption:', pt2)
# Out:
# This is round 0, right: bitarray('00100111001110111110011101111001'), left: bitarray('00000000111000000001110111010000')
# This is round 1, right: bitarray('00111000001110111110010000011011'), left: bitarray('00100111001110111110011101111001')
# This is round 2, right: bitarray('00011111111000000001111010110010'), left: bitarray('00111000001110111110010000011011')
# This is round 3, right: bitarray('00000000111000000001110111010000'), left: bitarray('00011111111000000001111010110010')
# This is round 4, right: bitarray('00100111001110111110011101111001'), left: bitarray('00000000111000000001110111010000')
# This is round 5, right: bitarray('00111000001110111110010000011011'), left: bitarray('00100111001110111110011101111001')
# This is round 6, right: bitarray('00011111111000000001111010110010'), left: bitarray('00111000001110111110010000011011')
# This is round 7, right: bitarray('00000000111000000001110111010000'), left: bitarray('00011111111000000001111010110010')
# This is round 8, right: bitarray('00100111001110111110011101111001'), left: bitarray('00000000111000000001110111010000')
# This is round 9, right: bitarray('00111000001110111110010000011011'), left: bitarray('00100111001110111110011101111001')
# This is round 10, right: bitarray('00011111111000000001111010110010'), left: bitarray('00111000001110111110010000011011')
# This is round 11, right: bitarray('00000000111000000001110111010000'), left: bitarray('00011111111000000001111010110010')
# This is round 12, right: bitarray('00100111001110111110011101111001'), left: bitarray('00000000111000000001110111010000')
# This is round 13, right: bitarray('00111000001110111110010000011011'), left: bitarray('00100111001110111110011101111001')
# This is round 14, right: bitarray('00011111111000000001111010110010'), left: bitarray('00111000001110111110010000011011')
# This is round 15, right: bitarray('00000000111000000001110111010000'), left: bitarray('00011111111000000001111010110010')
#
# Ciphertext after DES encryption: 48454C4C4F313233
# Now decrypting ciphertext
# This is round 0, right: bitarray('00100111001110111110011101111001'), left: bitarray('00000000111000000001110111010000')
# This is round 1, right: bitarray('00111000001110111110010000011011'), left: bitarray('00100111001110111110011101111001')
# This is round 2, right: bitarray('00011111111000000001111010110010'), left: bitarray('00111000001110111110010000011011')
# This is round 3, right: bitarray('00000000111000000001110111010000'), left: bitarray('00011111111000000001111010110010')
# This is round 4, right: bitarray('00100111001110111110011101111001'), left: bitarray('00000000111000000001110111010000')
# This is round 5, right: bitarray('00111000001110111110010000011011'), left: bitarray('00100111001110111110011101111001')
# This is round 6, right: bitarray('00011111111000000001111010110010'), left: bitarray('00111000001110111110010000011011')
# This is round 7, right: bitarray('00000000111000000001110111010000'), left: bitarray('00011111111000000001111010110010')
# This is round 8, right: bitarray('00100111001110111110011101111001'), left: bitarray('00000000111000000001110111010000')
# This is round 9, right: bitarray('00111000001110111110010000011011'), left: bitarray('00100111001110111110011101111001')
# This is round 10, right: bitarray('00011111111000000001111010110010'), left: bitarray('00111000001110111110010000011011')
# This is round 11, right: bitarray('00000000111000000001110111010000'), left: bitarray('00011111111000000001111010110010')
# This is round 12, right: bitarray('00100111001110111110011101111001'), left: bitarray('00000000111000000001110111010000')
# This is round 13, right: bitarray('00111000001110111110010000011011'), left: bitarray('00100111001110111110011101111001')
# This is round 14, right: bitarray('00011111111000000001111010110010'), left: bitarray('00111000001110111110010000011011')
# This is round 15, right: bitarray('00000000111000000001110111010000'), left: bitarray('00011111111000000001111010110010')
#
# Plaintext after DES decryption: HELLO123
