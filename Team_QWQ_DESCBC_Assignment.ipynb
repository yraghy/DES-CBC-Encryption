# %% [markdown]
# # Starter Notebook: DES Encryption with CBC Mode
#
# **FOR TA CORRECTING: install bitarray library on your ide so the code runs!!!**

# %%
from fontTools.misc.textTools import tobytes
from ruamel.yaml import round_trip_load

# DES Encryption with CBC Mode
# Group Members: Youssef Ahmed Elraghy / 13001467 / P02
#                Abdelrahman Mostafa   / 13002064 / P02

# DES Tables
IP = [58, 50, 42, 34, 26, 18, 10, 2, 60, 52, 44, 36, 28, 20, 12, 4,
      62, 54, 46, 38, 30, 22, 14, 6, 64, 56, 48, 40, 32, 24, 16, 8,
      57, 49, 41, 33, 25, 17, 9, 1, 59, 51, 43, 35, 27, 19, 11, 3,
      61, 53, 45, 37, 29, 21, 13, 5, 63, 55, 47, 39, 31, 23, 15, 7]

FP = [40, 8, 48, 16, 56, 24, 64, 32, 39, 7, 47, 15, 55, 23, 63, 31,
      38, 6, 46, 14, 54, 22, 62, 30, 37, 5, 45, 13, 53, 21, 61, 29,
      36, 4, 44, 12, 52, 20, 60, 28, 35, 3, 43, 11, 51, 19, 59, 27,
      34, 2, 42, 10, 50, 18, 58, 26, 33, 1, 41, 9, 49, 17, 57, 25]

E = [32, 1, 2, 3, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 10, 11, 12, 13, 12, 13, 14, 15, 16, 17,
     16, 17, 18, 19, 20, 21, 20, 21, 22, 23, 24, 25, 24, 25, 26, 27, 28, 29, 28, 29, 30, 31, 32, 1]

P = [16, 7, 20, 21, 29, 12, 28, 17, 1, 15, 23, 26, 5, 18, 31, 10,
     2, 8, 24, 14, 32, 27, 3, 9, 19, 13, 30, 6, 22, 11, 4, 25]

S_BOXES = [
    [[14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7],
     [0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8],
     [4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0],
     [15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13]],

    [[15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10],
     [3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5],
     [0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15],
     [13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9]],

    [[10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8],
     [13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1],
     [13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7],
     [1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12]],

    [[7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15],
     [13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9],
     [10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4],
     [3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14]],

    [[2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9],
     [14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6],
     [4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14],
     [11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3]],

    [[12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11],
     [10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8],
     [9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6],
     [4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13]],

    [[4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1],
     [13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6],
     [1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2],
     [6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12]],

    [[13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7],
     [1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2],
     [7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8],
     [2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11]]
]

# 16 round keys (48 bits each)
round_keys = ["010101010101010101010101010101010101010101010101" for _ in range(16)]

# %%
from bitarray import bitarray

# key rotations for proper results from feistel in DES only
def rotate_left(bits, n):
    return bits[n:] + bits[:n]

round_keys = [bitarray(key) for key in round_keys]
# call shift method on all round keys
for i in range(len(round_keys)):
    round_keys[i] = rotate_left(round_keys[i], i)
round_keys = [key.to01() for key in round_keys] # string to bits conv


# XOR method for xoring step of DES
def xor(b1, b2):
    return bitarray([b1[i] != b2[i] for i in range(len(b1))])

# text to bits conversion method (includes padding)
def t2b(text, size=64):
    bits = bitarray()
    bits.frombytes(text.encode('utf-8'))
    while len(bits) < size:
        bits.extend('0')
    return bits[:size]

# bits to text conversion method
def b2t(bits):
    return bits.tobytes().decode('utf-8', 'ignore')

# Permutation method -> swaps bits according to ptable
def permute(block, Ptable):
    return bitarray([block[i-1] for i in Ptable])

# s-box substitutions
def s_box(bits):
    output = bitarray()
    for i in range(8):
        chunk = bits[i*6:(i+1)*6]
        row = int(str(chunk[0]) + str(chunk[5]), 2)
        col = int(chunk[1:5].to01(), 2)
        output.extend(f"{S_BOXES[i][row][col]:04b}")
    return output

# feistel function method
def feistel(right, key):
    expand = permute(right, E)
    print(f"Expanded right: {expand}")
    xord = xor(expand, key)
    print(f"XOR with key: {xord}")
    sub = s_box(xord)
    print(f"S-box output: {sub}")
    return permute(sub, P)

# encryption function (combines all the helper/step methods we defined above)
def encrypt(pt, keys):
    bin_text = t2b(pt) # converts our plaintext into binary
    print(f"Binary text: {bin_text}")
    permuted = permute(bin_text, IP) # performs initial permutation on binary form of plaintext
    print(f"Initial permutation: {permuted}")
    left, right = permuted[:32], permuted[32:] # splits block into left and right segments
    print(f"Initial left: {left}, Initial right: {right}")
    # 16 rounds of feistel for 16 keys
    for i, key in enumerate(keys):
        new_r = xor(left, feistel(right, bitarray(key))) # gets new right by xoring the left block with the output of the feistel of the current right and key
        left, right = right, new_r # shifts so the left becomes the right and the right becomes the new right
        print(f"\nRound {i+1} - Left: {left}, Right: {right}")
    combined = left + right # combines the final blocks
    print(f"Combined before final permutation: {combined}")
    return permute(combined, FP) # performs permutation on the combined final blocks using the final permutation table (given)

# CBC mode ecrypt
def encrypt_cbc(pt, keys, iv):
    pt_blocks = [pt[i:i+8] for i in range(0, len(pt), 8)]
    iv_bits = t2b(iv)
    ciphertext = bitarray()
    for block in pt_blocks:
        block_bits = t2b(block) # switch block from text to binary
        block_bits = xor(block_bits, iv_bits) # xor block with the IV/prev_CT (CBC steps)
        ct_bits = encrypt(b2t(block_bits), keys) # encrypt the xored block
        ciphertext.extend(ct_bits) # add encrypted block to final ciphertext
        iv_bits = ct_bits # next iteration of IV is the current ciphertext(block)
    return ciphertext # returns ciphertext bits

# %% [markdown]
# **DES Encryption in CBC mode (>64-bit blocks + IVs)**

# %%
from bitarray import bitarray
iv = "12345678"  # Initialization vector
pt = "desHello more than 8 bytes"
ct = encrypt_cbc(pt, round_keys, iv)
print('\nCiphertext after DES encryption with CBC mode (binary):', ct)
hexct = ct.tobytes().hex()
print('Ciphertext after DES encryption with CBC mode (hex):', hexct)
ascii_ct = (bytes.fromhex(hexct)).decode('utf-8', 'ignore')
print('Ciphertext after DES encryption with CBC mode (ascii):', ascii_ct)
# encrypted text will only differ if the IV changes
# Out:
# Binary text: bitarray('0101010101010111010000000111110001010000010110100101101101010111')
# Initial permutation: bitarray('1111111111111011100010111100001100000000000010000110100011100010')
# Initial left: bitarray('11111111111110111000101111000011'), Initial right: bitarray('00000000000010000110100011100010')
# Expanded right: bitarray('000000000000000001010000001101010001011100000100')
# XOR with key: bitarray('010101010101010100000101011000000100001001010001')
# S-box output: bitarray('11000001110010111101101001001100')
#
# Round 1 - Left: bitarray('00000000000010000110100011100010'), Right: bitarray('01000110000011100100101010100011')
# Expanded right: bitarray('101000001100000001011100001001010101010100000110')
# XOR with key: bitarray('000010100110101011110110100011111111111110101100')
# S-box output: bitarray('01001011100111101000110100101110')
#
# Round 2 - Left: bitarray('01000110000011100100101010100011'), Right: bitarray('01011101010000101001110110001010')
# Expanded right: bitarray('001011111010101000000101010011111011110001010100')
# XOR with key: bitarray('011110101111111101010000000110101110100100000001')
# S-box output: bitarray('01110010001000010001001110110001')
#
# Round 3 - Left: bitarray('01011101010000101001110110001010'), Right: bitarray('10100100001011101110010010100100')
# Expanded right: bitarray('010100001000000101011101011100001001010100001001')
# XOR with key: bitarray('111110100010101111110111110110100011111110100011')
# S-box output: bitarray('00001110011110110101001100100001')
#
# Round 4 - Left: bitarray('10100100001011101110010010100100'), Right: bitarray('10111001001011111011000111011110')
# Expanded right: bitarray('010111110010100101011111110110100011111011111101')
# XOR with key: bitarray('000010100111110000001010100011110110101110101000')
# S-box output: bitarray('01000001101101101000101011101001')
#
# Round 5 - Left: bitarray('10111001001011111011000111011110'), Right: bitarray('10111001010111100011100110100001')
# Expanded right: bitarray('110111110010101011111100000111110011110100000011')
# XOR with key: bitarray('011101011000000001010110101101011001011110101001')
# S-box output: bitarray('00111100110101010010000000010100')
#
# Round 6 - Left: bitarray('10111001010111100011100110100001'), Right: bitarray('00111111001001101010001001101100')
# Expanded right: bitarray('000111111110100100001101010100000100001101011000')
# XOR with key: bitarray('010010101011110001011000000001010001011000001101')
# S-box output: bitarray('10101111010010111110011001010111')
#
# Round 7 - Left: bitarray('00111111001001101010001001101100'), Right: bitarray('01111010101000010111001101011001')
# Expanded right: bitarray('101111110101010100000010101110100110101011110010')
# XOR with key: bitarray('000101011111111110101000000100001100000001011000')
# S-box output: bitarray('01110101011111000100011011010101')
#
# Round 8 - Left: bitarray('01111010101000010111001101011001'), Right: bitarray('00111001000100110111100000010011')
# Expanded right: bitarray('100111110010100010100110101111110000000010100110')
# XOR with key: bitarray('110010100111110111110011111010100101010111110011')
# S-box output: bitarray('11000001001101000011001011001100')
#
# Round 9 - Left: bitarray('00111001000100110111100000010011'), Right: bitarray('01010110000100011010001111111100')
# Expanded right: bitarray('001010101100000010100011110100000111111111111000')
# XOR with key: bitarray('100000000110101000001001011110101101010101010010')
# S-box output: bitarray('01001110100001101001111101011001')
#
# Round 10 - Left: bitarray('01010110000100011010001111111100'), Right: bitarray('01000010011010111100000100001011')
# Expanded right: bitarray('101000000100001101010111111000000010100001010110')
# XOR with key: bitarray('111101010001011000000010101101010111110100000011')
# S-box output: bitarray('01101100101111010010111001101111')
#
# Round 11 - Left: bitarray('01000010011010111100000100001011'), Right: bitarray('11001010001010110011110000000000')
# Expanded right: bitarray('011001010100000101010110100111111000000000000001')
# XOR with key: bitarray('110011111110101111111100001101010010101010101011')
# S-box output: bitarray('10111111011110001101110100111010')
#
# Round 12 - Left: bitarray('11001010001010110011110000000000'), Right: bitarray('00111101111001001010011101010101')
# Expanded right: bitarray('100111111011111100001001010100001110101010101010')
# XOR with key: bitarray('110010101110101001011100000001011011111111111111')
# S-box output: bitarray('11000001011001001110101111001011')
#
# Round 13 - Left: bitarray('00111101111001001010011101010101'), Right: bitarray('11010011100111001100010010000101')
# Expanded right: bitarray('111010100111110011111001011000001001010000001011')
# XOR with key: bitarray('010000001101011001010011110010100011111010100001')
# S-box output: bitarray('00111000110001111001001101010010')
#
# Round 14 - Left: bitarray('11010011100111001100010010000101'), Right: bitarray('10011110100111111001010001010111')
# Expanded right: bitarray('110011111101010011111111110010101000001010101111')
# XOR with key: bitarray('100110101000000110101010100111111101011111111010')
# S-box output: bitarray('10001010111010110111100001100011')
#
# Round 15 - Left: bitarray('10011110100111111001010001010111'), Right: bitarray('00100011010000111100100101000001')
# Expanded right: bitarray('100100000110101000000111111001010010101000000010')
# XOR with key: bitarray('001110101100000010101101010011111000000010101000')
# S-box output: bitarray('10001101000011010000000110111001')
#
# Round 16 - Left: bitarray('00100011010000111100100101000001'), Right: bitarray('00010100000101111110100000000110')
# Combined before final permutation: bitarray('0010001101000011110010010100000100010100000101111110100000000110')
# Binary text: bitarray('0101010100011111011111100110100001101001011001000000000000000000')
# Initial permutation: bitarray('0011110100000111001001110001001100000000001111000001111000000110')
# Initial left: bitarray('00111101000001110010011100010011'), Initial right: bitarray('00000000001111000001111000000110')
# Expanded right: bitarray('000000000000000111111000000011111100000000001100')
# XOR with key: bitarray('010101010101010010101101010110101001010101011001')
# S-box output: bitarray('11000001110111011111100101010000')
#
# Round 1 - Left: bitarray('00000000001111000001111000000110'), Right: bitarray('10001010100100101101011011010011')
# Expanded right: bitarray('110001010101010010100101011010101101011010100111')
# XOR with key: bitarray('011011111111111000001111110000000111110000001101')
# S-box output: bitarray('01011001010100111111001010100111')
#
# Round 2 - Left: bitarray('10001010100100101101011011010011'), Right: bitarray('10100101010100111101001010100101')
# Expanded right: bitarray('110100001010101010100111111010100101010100001011')
# XOR with key: bitarray('100001011111111111110010101111110000000001011110')
# S-box output: bitarray('11110101110000011101011111010111')
#
# Round 3 - Left: bitarray('10100101010100111101001010100101'), Right: bitarray('00101001001001010011110111101000')
# Expanded right: bitarray('000101010010100100001010100111111011111101010000')
# XOR with key: bitarray('101111111000001110100000001101010001010111111010')
# S-box output: bitarray('01111001010110101101011011000011')
#
# Round 4 - Left: bitarray('00101001001001010011110111101000'), Right: bitarray('10000000001011000001100011101110')
# Expanded right: bitarray('010000000000000101011000000011110001011101011101')
# XOR with key: bitarray('000101010101010000001101010110100100001000001000')
# S-box output: bitarray('01110001000100001111111111110110')
#
# Round 5 - Left: bitarray('10000000001011000001100011101110'), Right: bitarray('00011110000100111101101101000011')
# Expanded right: bitarray('100011111100000010100111111011110110101000000110')
# XOR with key: bitarray('001001010110101000001101010001011100000010101100')
# S-box output: bitarray('11101101100000000101010110111110')
#
# Round 6 - Left: bitarray('00011110000100111101101101000011'), Right: bitarray('10101010101000101111111111010111')
# Expanded right: bitarray('110101010101010100000101011111111111111010101111')
# XOR with key: bitarray('100000000000000001010000001010101010101111111010')
# S-box output: bitarray('01001111110100011010100001110011')
#
# Round 7 - Left: bitarray('10101010101000101111111111010111'), Right: bitarray('11001001000010000001011011010011')
# Expanded right: bitarray('111001010010100001010000000010101101011010100111')
# XOR with key: bitarray('010011111000001011111010101000000111110000001101')
# S-box output: bitarray('01101001010000101010001010100111')
#
# Round 8 - Left: bitarray('11001001000010000001011011010011'), Right: bitarray('10101011110010010011000101110110')
# Expanded right: bitarray('010101010111111001010010100110100010101110101101')
# XOR with key: bitarray('000000000010101100000111110011110111111011111000')
# S-box output: bitarray('11100001001101011111011100101111')
#
# Round 9 - Left: bitarray('10101011110010010011000101110110'), Right: bitarray('01100100101011101110100001111111')
# Expanded right: bitarray('101100001001010101011101011101010000001111111110')
# XOR with key: bitarray('000110100011111111110111110111111010100101010100')
# S-box output: bitarray('00011000110010111001110111010011')
#
# Round 10 - Left: bitarray('01100100101011101110100001111111'), Right: bitarray('00011000100100100001100000111101')
# Expanded right: bitarray('100011110001010010100100000011110000000111111010')
# XOR with key: bitarray('110110100100000111110001010110100101010010101111')
# S-box output: bitarray('01110111100110011111001011001101')
#
# Round 11 - Left: bitarray('00011000100100100001100000111101'), Right: bitarray('10001001100110100010001110001100')
# Expanded right: bitarray('010001010011110011110100000100000111110001011001')
# XOR with key: bitarray('111011111001011001011110101110101101011011110011')
# S-box output: bitarray('00000000110011111000111111111100')
#
# Round 12 - Left: bitarray('10001001100110100010001110001100'), Right: bitarray('10000011111000110010110101010100')
# Expanded right: bitarray('010000000111111100000110100101011010101010101001')
# XOR with key: bitarray('000101010010101001010011110000001111111111111100')
# S-box output: bitarray('01110111011001111111010111000101')
#
# Round 13 - Left: bitarray('10000011111000110010110101010100'), Right: bitarray('01101000110011111101100100110011')
# Expanded right: bitarray('101101010001011001011111111011110010100110100110')
# XOR with key: bitarray('000111111011110011110101010001011000001100001100')
# S-box output: bitarray('01000101111101010101111010001011')
#
# Round 14 - Left: bitarray('01101000110011111101100100110011'), Right: bitarray('00111111110001001111010001001001')
# Expanded right: bitarray('100111111111111000001001011110101000001001010010')
# XOR with key: bitarray('110010101010101101011100001011111101011100000111')
# S-box output: bitarray('11000100100001000111100001101000')
#
# Round 15 - Left: bitarray('00111111110001001111010001001001'), Right: bitarray('01010000010110110100110010100011')
# Expanded right: bitarray('101010100000001011110110101001011001010100000110')
# XOR with key: bitarray('000000001010100001011100000011110011111110101100')
# S-box output: bitarray('11101011000101001011111000101110')
#
# Round 16 - Left: bitarray('01010000010110110100110010100011'), Right: bitarray('01000010011011100010001011100001')
# Combined before final permutation: bitarray('0101000001011011010011001010001101000010011011100010001011100001')
# Binary text: bitarray('0111001000000100000011000111000001001001011101110000000000000000')
# Initial permutation: bitarray('0011100100101001001001100011000000000000001010010001010000100001')
# Initial left: bitarray('00111001001010010010011000110000'), Initial right: bitarray('00000000001010010001010000100001')
# Expanded right: bitarray('100000000000000101010010100010101000000100000010')
# XOR with key: bitarray('110101010101010000000111110111111101010001010111')
# S-box output: bitarray('00110001000101011001100011101011')
#
# Round 1 - Left: bitarray('00000000001010010001010000100001'), Right: bitarray('10000100001110110111100000110011')
# Expanded right: bitarray('110000001000000111110110101111110000000110100111')
# XOR with key: bitarray('011010100010101101011100000101011010101100001101')
# S-box output: bitarray('10011110100001000010011101110111')
#
# Round 2 - Left: bitarray('10000100001110110111100000110011'), Right: bitarray('01000010100100110010100110011011')
# Expanded right: bitarray('101000000101010010100110100101010011110011110110')
# XOR with key: bitarray('111101010000000111110011110000000110100110100011')
# S-box output: bitarray('01101001100101001111111111010001')
#
# Round 3 - Left: bitarray('01000010100100110010100110011011'), Right: bitarray('10110011000001111000001110111010')
# Expanded right: bitarray('010110100110100000001111110000000111110111110101')
# XOR with key: bitarray('111100001100001010100101011010101101011101011111')
# S-box output: bitarray('01010011001100000000111110000010')
#
# Round 4 - Left: bitarray('10110011000001111000001110111010'), Right: bitarray('00010110101100011100100110010100')
# Expanded right: bitarray('000010101101010110100011111001010011110010101000')
# XOR with key: bitarray('010111111000000011110110101100000110100111111101')
# S-box output: bitarray('10111001011111100111111110000110')
#
# Round 5 - Left: bitarray('00010110101100011100100110010100'), Right: bitarray('10000111111010001111000101010101')
# Expanded right: bitarray('110000001111111101010001011110100010101010101011')
# XOR with key: bitarray('011010100101010111111011110100001000000000000001')
# S-box output: bitarray('10011010111001111100100101000001')
#
# Round 6 - Left: bitarray('10000111111010001111000101010101'), Right: bitarray('11000111011011001111000010010010')
# Expanded right: bitarray('011000001110101101011001011110100001010010100101')
# XOR with key: bitarray('001101011011111000001100001011110100000111110000')
# S-box output: bitarray('11011001010110010111010001110000')
#
# Round 7 - Left: bitarray('11000111011011001111000010010010'), Right: bitarray('00100001011101010011010110011111')
# Expanded right: bitarray('100100000010101110101010100110101011110011111110')
# XOR with key: bitarray('001110101000000100000000001100000001011001010100')
# S-box output: bitarray('10001010100101111011101000100011')
#
# Round 8 - Left: bitarray('00100001011101010011010110011111'), Right: bitarray('00110010100001101110110100010010')
# Expanded right: bitarray('000110100101010000001101011101011010100010100100')
# XOR with key: bitarray('010011110000000101011000001000001111110111110001')
# S-box output: bitarray('01100101000010110111010111111111')
#
# Round 9 - Left: bitarray('00110010100001101110110100010010'), Right: bitarray('10001011001000111101101101100110')
# Expanded right: bitarray('010001010110100100000111111011110110101100001101')
# XOR with key: bitarray('111011111100001110101101010001011100000110100111')
# S-box output: bitarray('00000010010111010101010111100111')
#
# Round 10 - Left: bitarray('10001011001000111101101101100110'), Right: bitarray('11010110100100011101000101111011')
# Expanded right: bitarray('111010101101010010100011111010100010101111110111')
# XOR with key: bitarray('101111111000000111110110101111110111111010100010')
# S-box output: bitarray('01111001100111101101011101011011')
#
# Round 11 - Left: bitarray('11010110100100011101000101111011'), Right: bitarray('10100100010111010010000000101100')
# Expanded right: bitarray('010100001000001011111010100100000000000101011001')
# XOR with key: bitarray('111110100010100001010000001110101010101111110011')
# S-box output: bitarray('00001110000100010110100001111100')
#
# Round 12 - Left: bitarray('10100100010111010010000000101100'), Right: bitarray('00001000100011011101010111001011')
# Expanded right: bitarray('100001010001010001011011111010101011111001010110')
# XOR with key: bitarray('110100000100000100001110101111111110101100000011')
# S-box output: bitarray('10011000100110101101011001111111')
#
# Round 13 - Left: bitarray('00001000100011011101010111001011'), Right: bitarray('10001011101000110010110101000110')
# Expanded right: bitarray('010001010111110100000110100101011010101000001101')
# XOR with key: bitarray('111011111101011110101100001111110000000010100111')
# S-box output: bitarray('00001110100001110001011110110111')
#
# Round 14 - Left: bitarray('10001011101000110010110101000110'), Right: bitarray('11101010111001111110100011110010')
# Expanded right: bitarray('011101010101011100001111111101010001011110100101')
# XOR with key: bitarray('001000000000001001011010101000000100001011110000')
# S-box output: bitarray('00101111001111001010101010010000')
#
# Round 15 - Left: bitarray('11101010111001111110100011110010'), Right: bitarray('11011100100010110111111110010011')
# Expanded right: bitarray('111011111001010001010110101111111111110010100111')
# XOR with key: bitarray('010001010011111011111100000101010101011000001101')
# S-box output: bitarray('10100000010110000010110101010111')
#
# Round 16 - Left: bitarray('11011100100010110111111110010011'), Right: bitarray('11111100011101001100001000011010')
# Combined before final permutation: bitarray('1101110010001011011111111001001111111100011101001100001000011010')
# Binary text: bitarray('0111000001101100000000000000000000000000000000000000000000000000')
# Initial permutation: bitarray('0000001100000001000000100000000000000000000000110000001000000000')
# Initial left: bitarray('00000011000000010000001000000000'), Initial right: bitarray('00000000000000110000001000000000')
# Expanded right: bitarray('000000000000000000000110100000000100000000000000')
# XOR with key: bitarray('010101010101010101010011110101010001010101010101')
# S-box output: bitarray('11000001010101110000011001010110')
#
# Round 1 - Left: bitarray('00000000000000110000001000000000'), Right: bitarray('10000101111100101101001000101000')
# Expanded right: bitarray('010000001011111110100101011010100100000101010001')
# XOR with key: bitarray('111010100001010100001111110000001110101111111011')
# S-box output: bitarray('10101101110000111111100001110101')
#
# Round 2 - Left: bitarray('10000101111100101101001000101000'), Right: bitarray('10110011110111100100110110110000')
# Expanded right: bitarray('010110100111111011111100001001011011110110100001')
# XOR with key: bitarray('000011110010101110101001011100001110100011110100')
# S-box output: bitarray('11111000000010101110100010111010')
#
# Round 3 - Left: bitarray('10110011110111100100110110110000'), Right: bitarray('10011110001111000101010011101011')
# Expanded right: bitarray('110011111100000111111000001010101001011101010111')
# XOR with key: bitarray('011001010110101101010010100000000011110111111101')
# S-box output: bitarray('10011101100000100100111111110110')
#
# Round 4 - Left: bitarray('10011110001111000101010011101011'), Right: bitarray('10100001001000000010100010001011')
# Expanded right: bitarray('110100000010100100000000000101010001010001010111')
# XOR with key: bitarray('100001010111110001010101010000000100000100000010')
# S-box output: bitarray('11111010010000101000101000100010')
#
# Round 5 - Left: bitarray('10100001001000000010100010001011'), Right: bitarray('11001111110101111101001011101001')
# Expanded right: bitarray('111001011111111010101111111010100101011101010011')
# XOR with key: bitarray('010011110101010000000101010000001111110111111001')
# S-box output: bitarray('01100111000110111000010111110011')
#
# Round 6 - Left: bitarray('11001111110101111101001011101001'), Right: bitarray('01100110011100101100011011010010')
# Expanded right: bitarray('001100001100001110100101011000001101011010100100')
# XOR with key: bitarray('011001011001011011110000001101011000001111110001')
# S-box output: bitarray('10010110101111111101111010101111')
#
# Round 7 - Left: bitarray('01100110011100101100011011010010'), Right: bitarray('00110010001100011100111110010110')
# Expanded right: bitarray('000110100100000110100011111001011111110010101100')
# XOR with key: bitarray('101100001110101100001001010011110101011000000110')
# S-box output: bitarray('00100100001101100000000101010100')
#
# Round 8 - Left: bitarray('00110010001100011100111110010110'), Right: bitarray('01100000001000101111010011100110')
# Expanded right: bitarray('001100000000000100000101011110101001011100001100')
# XOR with key: bitarray('011001010101010001010000001011111100001001011001')
# S-box output: bitarray('10010001001000010111101101000000')
#
# Round 9 - Left: bitarray('01100000001000101111010011100110'), Right: bitarray('10000010100001011010111100010000')
# Expanded right: bitarray('010000000101010000001011110101011110100010100001')
# XOR with key: bitarray('111010101111111010100001011111110100001000001011')
# S-box output: bitarray('10100010101000110110010011110011')
#
# Round 10 - Left: bitarray('10000010100001011010111100010000'), Right: bitarray('10100010111101001111101101101011')
# Expanded right: bitarray('110100000101011110101001011111110110101101010111')
# XOR with key: bitarray('100001010000001011111100001010100011111000000010')
# S-box output: bitarray('11111001010010001010001100000010')
#
# Round 11 - Left: bitarray('10100010111101001111101101101011'), Right: bitarray('10000011001011100100110111010010')
# Expanded right: bitarray('010000000110100101011100001001011011111010100101')
# XOR with key: bitarray('111010101100001111110110100011110001010000001111')
# S-box output: bitarray('10101101101011101000101100110100')
#
# Round 12 - Left: bitarray('10000011001011100100110111010010'), Right: bitarray('10110001000111001000110000011111')
# Expanded right: bitarray('110110100010100011111001010001011000000011111111')
# XOR with key: bitarray('100011110111110110101100000100001101010110101010')
# S-box output: bitarray('11001100110001110100100101111100')
#
# Round 13 - Left: bitarray('10110001000111001000110000011111'), Right: bitarray('00011001111100111111100011100010')
# Expanded right: bitarray('000011110011111110100111111111110001011100000100')
# XOR with key: bitarray('101001011001010100001101010101011011110110101110')
# S-box output: bitarray('01000110110000001111101110000010')
#
# Round 14 - Left: bitarray('00011001111100111111100011100010'), Right: bitarray('11000000001110110010110110001110')
# Expanded right: bitarray('011000000000000111110110100101011011110001011101')
# XOR with key: bitarray('001101010101010010100011110000001110100100001000')
# S-box output: bitarray('11010001110111111111100010110110')
#
# Round 15 - Left: bitarray('11000000001110110010110110001110'), Right: bitarray('10101110001101000010110100000001')
# Expanded right: bitarray('110101011100000110101000000101011010100000000011')
# XOR with key: bitarray('011111110110101100000010101111110000001010101001')
# S-box output: bitarray('10000110001111011101011100000100')
#
# Round 16 - Left: bitarray('10101110001101000010110100000001'), Right: bitarray('00100101100111110001110111110010')
# Combined before final permutation: bitarray('1010111000110100001011010000000100100101100111110001110111110010')
#
# Ciphertext after DES encryption with CBC mode (binary): bitarray('')
# Ciphertext after DES encryption with CBC mode (hex): 7572a20ca0481d0c13b92434502bf603151fe4d6e7a4ecd9ad62fc6c3ad60262
# Ciphertext after DES encryption with CBC mode (ascii): urH$4P+٭bl:b

# %% [markdown]
# **DES only encryption for 64-bit block**

# %%
from bitarray import bitarray
pt = "DESHello"
ct = encrypt(pt, round_keys)
print('\nCiphertext after DES only (binary): ', ct)
hexct = ct.tobytes().hex()
print('\nCiphertext after DES only (hex): ', hexct)
ascii_ct = (bytes.fromhex(hexct)).decode('utf-8', 'ignore')
print('\nCiphertext after DES only (ascii): ', ascii_ct)
# Out:
# Binary text: bitarray('0100010001000101010100110100100001100101011011000110110001101111')
# Initial permutation: bitarray('1111111100000100111100111001011000000000111100001110100010000100')
# Initial left: bitarray('11111111000001001111001110010110'), Initial right: bitarray('00000000111100001110100010000100')
# Expanded right: bitarray('000000000001011110100001011101010001010000001000')
# XOR with key: bitarray('010101010100001011110100001000000100000101011101')
# S-box output: bitarray('11000010010000110111101010111001')
#
# Round 1 - Left: bitarray('00000000111100001110100010000100'), Right: bitarray('00000101111000010111111100010111')
# Expanded right: bitarray('100000001011111100000010101111111110100010101110')
# XOR with key: bitarray('001010100001010110101000000101010100001000000100')
# S-box output: bitarray('11111101011111000010001111111000')
#
# Round 2 - Left: bitarray('00000101111000010111111100010111'), Right: bitarray('00001110010010010001111001010011')
# Expanded right: bitarray('100001011100001001010010100011111100001010100110')
# XOR with key: bitarray('110100001001011100000111110110101001011111110011')
# S-box output: bitarray('10011111001001010101100101101100')
#
# Round 3 - Left: bitarray('00001110010010010001111001010011'), Right: bitarray('11111101011111010000101100100001')
# Expanded right: bitarray('111111111010101111111010100001010110100100000011')
# XOR with key: bitarray('010101010000000101010000001011111100001110101001')
# S-box output: bitarray('11001001000000010111101111010100')
#
# Round 4 - Left: bitarray('11111101011111010000101100100001'), Right: bitarray('10111100111101011111111011110010')
# Expanded right: bitarray('010111111001011110101011111111111101011110100101')
# XOR with key: bitarray('000010101100001011111110101010101000001011110000')
# S-box output: bitarray('01001101010001001101001010010000')
#
# Round 5 - Left: bitarray('10111100111101011111111011110010'), Right: bitarray('11011110010100001101101100110000')
# Expanded right: bitarray('011011111100001010100001011011110110100110100001')
# XOR with key: bitarray('110001010110100000001011110001011100001100001011')
# S-box output: bitarray('01011101110111110110010110000011')
#
# Round 6 - Left: bitarray('11011110010100001101101100110000'), Right: bitarray('00111000101110100000011100101001')
# Expanded right: bitarray('100111110001010111110100000000001110100101010010')
# XOR with key: bitarray('110010100100000010100001010101011011110000000111')
# S-box output: bitarray('11000111000000111111101110101000')
#
# Round 7 - Left: bitarray('00111000101110100000011100101001'), Right: bitarray('00100111101101000011111110100001')
# Expanded right: bitarray('100100001111110110101000000111111111110100000010')
# XOR with key: bitarray('001110100101011100000010101101010101011110101000')
# S-box output: bitarray('10001010001011010010110100011001')
#
# Round 8 - Left: bitarray('00100111101101000011111110100001'), Right: bitarray('11100010001100100011111111100101')
# Expanded right: bitarray('111100000100000110100100000111111111111100001011')
# XOR with key: bitarray('101001010001010011110001010010101010101001011110')
# S-box output: bitarray('01001100100010010101100000010111')
#
# Round 9 - Left: bitarray('11100010001100100011111111100101'), Right: bitarray('10010101101110101011011011010001')
# Expanded right: bitarray('110010101011110111110101010110101101011010100011')
# XOR with key: bitarray('011000000001011101011111111100000111110000001001')
# S-box output: bitarray('01010011111110010000001010101010')
#
# Round 10 - Left: bitarray('10010101101110101011011011010001'), Right: bitarray('00101110000100011111101010100010')
# Expanded right: bitarray('000101011100000010100011111111110101010100000100')
# XOR with key: bitarray('010000001001010111110110101010100000000001010001')
# S-box output: bitarray('00111111111011101101100111011100')
#
# Round 11 - Left: bitarray('00101110000100011111101010100010'), Right: bitarray('11101110111001111100010110100110')
# Expanded right: bitarray('011101011101011100001111111000001011110100001101')
# XOR with key: bitarray('110111110111110110100101010010100001011110100111')
# S-box output: bitarray('11101100110000000101010000010111')
#
# Round 12 - Left: bitarray('11101110111001111100010110100110'), Right: bitarray('00001100100111100111000110011010')
# Expanded right: bitarray('000001011001010011111100001110100011110011110100')
# XOR with key: bitarray('010100001100000110101001011011110110100110100001')
# S-box output: bitarray('01100011111010101001101011010010')
#
# Round 13 - Left: bitarray('00001100100111100111000110011010'), Right: bitarray('10011101100101000000011011100011')
# Expanded right: bitarray('110011111011110010101000000000001101011100000111')
# XOR with key: bitarray('011001010001011000000010101010100111110110101101')
# S-box output: bitarray('10011100101111011101110010001000')
#
# Round 14 - Left: bitarray('10011101100101000000011011100011'), Right: bitarray('10110001000100100110000011000101')
# Expanded right: bitarray('110110100010100010100100001100000001011000001011')
# XOR with key: bitarray('100011110111110111110001011001010100001101011110')
# S-box output: bitarray('11001100001110010011001100010111')
#
# Round 15 - Left: bitarray('10110001000100100110000011000101'), Right: bitarray('00111011001111101010111000010111')
# Expanded right: bitarray('100111110110100111111101010101011100000010101110')
# XOR with key: bitarray('001101011100001101010111111111110110101000000100')
# S-box output: bitarray('11010101011011000011101011001000')
#
# Round 16 - Left: bitarray('00111011001111101010111000010111'), Right: bitarray('10001001101000111011000000010010')
# Combined before final permutation: bitarray('0011101100111110101011100001011110001001101000111011000000010010')
#
# Ciphertext after DES only (binary):  bitarray('1110000101110111000101011101010001011011011111000000000010101100')
#
# Ciphertext after DES only (hex):  e17715d45b7c00ac
#
# Ciphertext after DES only (ascii):  w[|
